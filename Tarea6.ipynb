# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgejosht/daa_2021_1/blob/master/Tarea6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
texto='El lema que anima a la Universidad Nacional, Por mi raza hablará el espíritu, revela la vocación humanística con la que fue concebida. El autor de esta célebre frase, José Vasconcelos, asumió la rectoría en 1920, en una época en que las esperanzas de la Revolución aún estaban vivas, había una gran fe en la Patria y el ánimo redentor se extendía en el ambiente.'
texto1=texto.replace(",", "")
texto2=texto1.replace(".","")
normalizado=texto2.lower()
separado=normalizado.split()
comparacion=separado
lista_n= []
for i in separado:
  if i not in lista_n:
    lista_n.append(i)
for palabra in lista_n:
  aparicion=0
  print(f"Frecuencia de la palabra '{palabra}':", end=" ")
  for palabra2 in comparacion:
    if palabra==palabra2:
      aparicion=aparicion+1
  print(f"{aparicion} \n")
# Out:
# Frecuencia de la palabra 'el': 5
#
# Frecuencia de la palabra 'lema': 1
#
# Frecuencia de la palabra 'que': 3
#
# Frecuencia de la palabra 'anima': 1
#
# Frecuencia de la palabra 'a': 1
#
# Frecuencia de la palabra 'la': 6
#
# Frecuencia de la palabra 'universidad': 1
#
# Frecuencia de la palabra 'nacional': 1
#
# Frecuencia de la palabra 'por': 1
#
# Frecuencia de la palabra 'mi': 1
#
# Frecuencia de la palabra 'raza': 1
#
# Frecuencia de la palabra 'hablará': 1
#
# Frecuencia de la palabra 'espíritu': 1
#
# Frecuencia de la palabra 'revela': 1
#
# Frecuencia de la palabra 'vocación': 1
#
# Frecuencia de la palabra 'humanística': 1
#
# Frecuencia de la palabra 'con': 1
#
# Frecuencia de la palabra 'fue': 1
#
# Frecuencia de la palabra 'concebida': 1
#
# Frecuencia de la palabra 'autor': 1
#
# Frecuencia de la palabra 'de': 2
#
# Frecuencia de la palabra 'esta': 1
#
# Frecuencia de la palabra 'célebre': 1
#
# Frecuencia de la palabra 'frase': 1
#
# Frecuencia de la palabra 'josé': 1
#
# Frecuencia de la palabra 'vasconcelos': 1
#
# Frecuencia de la palabra 'asumió': 1
#
# Frecuencia de la palabra 'rectoría': 1
#
# Frecuencia de la palabra 'en': 5
#
# Frecuencia de la palabra '1920': 1
#
# Frecuencia de la palabra 'una': 2
#
# Frecuencia de la palabra 'época': 1
#
# Frecuencia de la palabra 'las': 1
#
# Frecuencia de la palabra 'esperanzas': 1
#
# Frecuencia de la palabra 'revolución': 1
#
# Frecuencia de la palabra 'aún': 1
#
# Frecuencia de la palabra 'estaban': 1
#
# Frecuencia de la palabra 'vivas': 1
#
# Frecuencia de la palabra 'había': 1
#
# Frecuencia de la palabra 'gran': 1
#
# Frecuencia de la palabra 'fe': 1
#
# Frecuencia de la palabra 'patria': 1
#
# Frecuencia de la palabra 'y': 1
#
# Frecuencia de la palabra 'ánimo': 1
#
# Frecuencia de la palabra 'redentor': 1
#
# Frecuencia de la palabra 'se': 1
#
# Frecuencia de la palabra 'extendía': 1
#
# Frecuencia de la palabra 'ambiente': 1
